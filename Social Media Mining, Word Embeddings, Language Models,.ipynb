# %% [markdown]
# Deliverable 1

# %%
import nltk
from nltk.corpus import movie_reviews
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
documents = [list(movie_reviews.words(fileid)) for fileid in movie_reviews.fileids()]

# %% [markdown]
# Deliverable 2

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=documents, vector_size=50, window=5, min_count=2, workers=4)

# %% [markdown]
# Deliverable 3

# %%
king_vector = model.wv['king']
print(king_vector)
# Out:
# [-0.31911802 -0.38836443  0.5564782   0.44644696  0.29045752 -0.04405976
#   1.3938549  -0.50999796 -0.9195038  -0.0594677   1.2056434  -0.87399894
#   0.82172215  0.03988627  0.86668    -0.28278276 -0.565837    0.44220883
#  -0.9176608  -1.1447767   0.9394889   0.4523245   1.5259355  -0.8543301
#   0.55177295 -0.17563383  0.73074573 -0.7435997  -0.19656047 -0.18587671
#  -0.44517046 -0.7451556   0.45889986  0.46602768 -0.53782874  0.33238953
#  -0.94727004  1.4856758  -0.3016668  -0.0786424   0.31477413  0.46597713
#  -0.43680122 -0.10984704  1.3528483   0.41798976 -0.23367707 -0.04481812
#  -0.1046503   0.21934848]

# %% [markdown]
# Deliverable 4

# %%
similar_words = model.wv.most_similar('king', topn=5)
print(similar_words)
# Out:
# [('williamson', 0.8618090152740479), ('captain', 0.8405863046646118), ('dawes', 0.826160192489624), ('jerry', 0.825776994228363), ('forster', 0.8228055834770203)]

# %% [markdown]
# Deliverable 5

# %%
result = model.wv.most_similar(positive=['king', 'woman'], negative=['man'], topn=1)
print(result)
# Out:
# [('commanding', 0.8485694527626038)]

# %% [markdown]
# Deliverable 6

# %%
from transformers import pipeline
generator = pipeline('text-generation', model='gpt2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
generator.tokenizer.pad_token_id = generator.model.config.eos_token_id
text = generator(
 "Once upon a time",
 max_new_tokens=100,
 num_return_sequences=5
)
print(text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Once upon a time the king of the great land of the Great Sea began to stir, and all went astray, and to the sea a great sea of white marble that stood at the mouth of the sea, so that all the sea's inhabitants saw it, and so forth. This sea became an ark and became an empire. And there is still great wonder amongst those who are able to make such a discovery.\n\nThe king and his people had this idea on the first day, when they saw the"}, {'generated_text': "Once upon a time, it was just another normal human. That's that. Those weren't supposed to be this easy, huh? They probably had the same plan as me. Don't get out, you fool! If it wasn't for your good intentions and your own good intentions, I'd never have gotten out with you. But the plan changed, and I told you that this was not the time, that this was the start of our fight. No. We'll break these bones of yours in an instant"}, {'generated_text': 'Once upon a time, that world, or its inhabitants, did not appear for their own sake. And this is the fact, which I say is too obvious, and which is not here spoken of without occasion, for the greater part of the same cause has been brought to mind by the man who came to me to say of the first man (of whom he is a man of many names and manners) that, before he gave orders for it to be completed, what would he make that order, by himself on'}, {'generated_text': 'Once upon a time, even the most stubborn of adventurers found inspiration to seek out and study the teachings laid down in the many books they read. Their first thought, and very likely the most critical thought of all, in the pages of the most ancient of books, was "Let it Be."\n\nNow that the mind has been liberated from distraction, and even that was possible in the midst of all this, it is now a different matter.\n\nThe new age is coming for the new heroes of humanity.'}, {'generated_text': 'Once upon a time, the world would be free of tyranny and all forms of oppression or tyranny. You would be free from the darkness of tyranny. You would become your own judge, for there would never be another ruler in the world who would stand up to injustice. You would receive justice, equality and a great respect for each other."\n\n\nHe was already well on his way. Then he heard the voice of the man who had helped him. "Greetings, old man."\n\n\nThe man who was'}]
